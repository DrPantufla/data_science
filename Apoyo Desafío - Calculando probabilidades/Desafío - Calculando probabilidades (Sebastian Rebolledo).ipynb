# %% [markdown]
# **Desafio 1**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("worldcup2014.csv")

# %%
df.head()
# Out:
#           team     continent group  group_pos  cantidad_juegos  \
# 0       Brazil  southamerica     A          1                3
# 1       Mexico  northamerica     A          2                3
# 2      Croatia        europe     A          3                3
# 3     Cameroon        africa     A          4                3
# 4  Netherlands        europe     B          1                3
#
#    juegos_ganados  juegos_empatados  juegos_perdidos  goles_favor  \
# 0               2                 1                0            7
# 1               2                 1                0            4
# 2               1                 0                2            6
# 3               0                 0                3            1
# 4               3                 0                0           10
#
#    goles_contra goles_diferencia  puntos  clasificado
# 0             2                5       7            1
# 1             1                3       7            1
# ...

# %% [markdown]
# **Desafio 2**

# %%
df["continent"].value_counts()
# Out:
# europe          13
# southamerica     6
# africa           5
# asia             4
# northamerica     4
# Name: continent, dtype: int64

# %% [markdown]
# ¿Cuál es el continente con una mayor presencia en la muestra?

# %%
(df["continent"].value_counts('%'))*100
# Out:
# europe          40.625
# southamerica    18.750
# africa          15.625
# asia            12.500
# northamerica    12.500
# Name: continent, dtype: float64

# %% [markdown]
# Segun lo observado en la tabla de arriba, Europa tiene la mayor presencia en la muestra con un 40,625%

# %% [markdown]
# ¿Cuál es la probabilidad de elegir un equipo asiático al azar?

# %%
df['continent'].value_counts().sum()
# Out:
# 32

# %%
df['continent'].value_counts()['asia']
# Out:
# 4

# %%
(df['continent'].value_counts()['asia']/df['continent'].value_counts().sum())*100
# Out:
# 12.5

# %% [markdown]
# La probabilidad de elegir un equipo asiatico al azar es de 12.5%

# %% [markdown]
# ¿Cuál es la probabilidad de elegir un equipo africano al azar?

# %%
(df['continent'].value_counts()['africa']/df['continent'].value_counts().sum())*100
# Out:
# 15.625

# %% [markdown]
# La probabilidad de elegir un equipo africano al azar es de un 15,6%

# %% [markdown]
# **Desafio 3**

# %%
df_asia = df[df['continent'] == 'asia'] 
df_asia
# Out:
#            team continent group  group_pos  cantidad_juegos  juegos_ganados  \
# 7     Australia      asia     B          4                3               0
# 11        Japan      asia     C          4                3               0
# 23         Iran      asia     F          4                3               0
# 31  South Korea      asia     H          4                3               0
#
#     juegos_empatados  juegos_perdidos  goles_favor  goles_contra  \
# 7                  0                3            3             9
# 11                 1                2            2             6
# 23                 1                2            1             4
# 31                 1                2            3             6
#
#    goles_diferencia  puntos  clasificado
# 7                −6       0            0
# 11               −4       1            0
# 23               −3       1            0
# 31               −3       1            0

# %%
df_africa = df[df['continent'] == 'africa']
df_africa
# Out:
#            team continent group  group_pos  cantidad_juegos  juegos_ganados  \
# 3      Cameroon    africa     A          4                3               0
# 10  Ivory Coast    africa     C          3                3               1
# 21      Nigeria    africa     F          2                3               1
# 27        Ghana    africa     G          4                3               0
# 29      Algeria    africa     H          2                3               1
#
#     juegos_empatados  juegos_perdidos  goles_favor  goles_contra  \
# 3                  0                3            1             9
# 10                 0                2            4             5
# 21                 1                1            3             3
# 27                 1                2            4             6
# 29                 1                1            6             5
#
#    goles_diferencia  puntos  clasificado
# 3                −8       0            0
# ...

# %%
df_northamerica = df[df['continent'] == 'northamerica']
df_northamerica
# Out:
#              team     continent group  group_pos  cantidad_juegos  \
# 1          Mexico  northamerica     A          2                3
# 12     Costa Rica  northamerica     D          1                3
# 19       Honduras  northamerica     E          4                3
# 25  United States  northamerica     G          2                3
#
#     juegos_ganados  juegos_empatados  juegos_perdidos  goles_favor  \
# 1                2                 1                0            4
# 12               2                 1                0            4
# 19               0                 0                3            1
# 25               1                 1                1            4
#
#     goles_contra goles_diferencia  puntos  clasificado
# 1              1                3       7            1
# 12             1                3       7            1
# 19             8               −7       0            0
# 25             4                0       4            1

# %%
df_europe = df[df['continent'] == 'europe']
df_europe
# Out:
#                       team continent group  group_pos  cantidad_juegos  \
# 2                  Croatia    europe     A          3                3
# 4              Netherlands    europe     B          1                3
# 6                    Spain    europe     B          3                3
# 9                   Greece    europe     C          2                3
# 14                   Italy    europe     D          3                3
# 15                 England    europe     D          4                3
# 16                  France    europe     E          1                3
# 17             Switzerland    europe     E          2                3
# 22  Bosnia and Herzegovina    europe     F          3                3
# 24                 Germany    europe     G          1                3
# 26                Portugal    europe     G          3                3
# 28                 Belgium    europe     H          1                3
# ...

# %%
df_southamerica = df[df['continent'] == 'southamerica']
df_southamerica
# Out:
#          team     continent group  group_pos  cantidad_juegos  juegos_ganados  \
# 0      Brazil  southamerica     A          1                3               2
# 5       Chile  southamerica     B          2                3               2
# 8    Colombia  southamerica     C          1                3               3
# 13    Uruguay  southamerica     D          2                3               2
# 18    Ecuador  southamerica     E          3                3               1
# 20  Argentina  southamerica     F          1                3               3
#
#     juegos_empatados  juegos_perdidos  goles_favor  goles_contra  \
# 0                  1                0            7             2
# 5                  0                1            5             3
# 8                  0                0            9             2
# 13                 0                1            4             4
# 18                 1                1            3             3
# ...

# %% [markdown]
# **Desafio 4**

# %%
clasificado_por_continent = df.groupby(['continent']).mean()
clasificado_por_continent
# Out:
#               group_pos  cantidad_juegos  juegos_ganados  juegos_empatados  \
# continent
# africa         3.000000              3.0        0.600000          0.600000
# asia           4.000000              3.0        0.000000          0.750000
# europe         2.307692              3.0        1.384615          0.538462
# northamerica   2.250000              3.0        1.250000          0.750000
# southamerica   1.666667              3.0        2.166667          0.333333
#
#               juegos_perdidos  goles_favor  goles_contra    puntos  \
# continent
# africa               1.800000     3.600000      5.600000  2.400000
# asia                 2.250000     2.250000      6.250000  0.750000
# europe               1.076923     4.769231      4.000000  4.692308
# northamerica         1.000000     3.250000      3.500000  4.500000
# southamerica         0.500000     5.666667      2.833333  6.833333
#
#               clasificado
# continent
# africa           0.400000
# ...

# %%
clasificado_por_continent['clasificado']*100
# Out:
# continent
# africa          40.000000
# asia             0.000000
# europe          46.153846
# northamerica    75.000000
# southamerica    83.333333
# Name: clasificado, dtype: float64

# %% [markdown]
# En la tabla anterior se puede ver la probabilidad de que un pais clasifique por continente.

# %% [markdown]
# Un pais de Africa tiene un 40% de probabilidades de clasificar.

# %% [markdown]
# Un pais de Asia tiene un 0% de probabilidades de clasificar.

# %% [markdown]
# Un pais de Europa tiene un 46% de probabilidades de clasificar.

# %% [markdown]
# Un pais de Northamerica tiene un 75% de probabilidades de clasificar.

# %% [markdown]
# Un pais de Southamerica tiene un 83% de probabilidades de clasificar.

# %% [markdown]
# ***¿Cuál es la probabilidad de que un país asiático pase a la siguiente ronda?***

# %% [markdown]
# La probabilidad es de 0%

# %% [markdown]
# ***¿Cuáles son los dos continentes con la mayor probabilidad de clasificar?***

# %% [markdown]
# Southamerica y Northamerica

# %% [markdown]
# ***¿Cuál es la probabilidad de que un país europeo no clasifique?***

# %%
(1-clasificado_por_continent['clasificado']['europe'])*100
# Out:
# 53.84615384615385

# %% [markdown]
# La probabilidad de que un pais europeo no clasifique es: 53.84%

# %% [markdown]
# **Desafio 5**

# %%
df['ha_ganado'] = np.where(df['juegos_ganados'] == 0, 0, 1)

# %%
df
# Out:
#                       team     continent group  group_pos  cantidad_juegos  \
# 0                   Brazil  southamerica     A          1                3
# 1                   Mexico  northamerica     A          2                3
# 2                  Croatia        europe     A          3                3
# 3                 Cameroon        africa     A          4                3
# 4              Netherlands        europe     B          1                3
# 5                    Chile  southamerica     B          2                3
# 6                    Spain        europe     B          3                3
# 7                Australia          asia     B          4                3
# 8                 Colombia  southamerica     C          1                3
# 9                   Greece        europe     C          2                3
# 10             Ivory Coast        africa     C          3                3
# ...

# %%
df.groupby(['continent']).mean()
# Out:
#               group_pos  cantidad_juegos  juegos_ganados  juegos_empatados  \
# continent
# africa         3.000000              3.0        0.600000          0.600000
# asia           4.000000              3.0        0.000000          0.750000
# europe         2.307692              3.0        1.384615          0.538462
# northamerica   2.250000              3.0        1.250000          0.750000
# southamerica   1.666667              3.0        2.166667          0.333333
#
#               juegos_perdidos  goles_favor  goles_contra    puntos  \
# continent
# africa               1.800000     3.600000      5.600000  2.400000
# asia                 2.250000     2.250000      6.250000  0.750000
# europe               1.076923     4.769231      4.000000  4.692308
# northamerica         1.000000     3.250000      3.500000  4.500000
# southamerica         0.500000     5.666667      2.833333  6.833333
#
#               clasificado  ha_ganado
# continent
# africa           0.400000   0.600000
# ...

# %% [markdown]
# ***¿Qué continente tiene la mayor probabilidad de tener países con al menos 1
# victoria?***

# %% [markdown]
# Basado en el cuadro de arriba, el continente con mayor probabilidad de tener paises con al menos 1 victoria es Southamerica.

# %% [markdown]
# ***¿Qué continente tiene un nivel similar entre países que tienen o no tienen
# victorias?***

# %% [markdown]
# El continente que tiene un porcentaje más cercano al 50%, es africa con un 60%.

# %% [markdown]
# **Reformule el código para juegos perdidos y analice los continentes con mayor
# probabilidad de tener países sin juegos perdidos.**

# %%
df['ha_perdido'] = np.where(df['juegos_perdidos']==0, 1, 0)

# %%
df
# Out:
#                       team     continent group  group_pos  cantidad_juegos  \
# 0                   Brazil  southamerica     A          1                3
# 1                   Mexico  northamerica     A          2                3
# 2                  Croatia        europe     A          3                3
# 3                 Cameroon        africa     A          4                3
# 4              Netherlands        europe     B          1                3
# 5                    Chile  southamerica     B          2                3
# 6                    Spain        europe     B          3                3
# 7                Australia          asia     B          4                3
# 8                 Colombia  southamerica     C          1                3
# 9                   Greece        europe     C          2                3
# 10             Ivory Coast        africa     C          3                3
# ...

# %%
df.groupby(['continent']).mean()
# Out:
#               group_pos  cantidad_juegos  juegos_ganados  juegos_empatados  \
# continent
# africa         3.000000              3.0        0.600000          0.600000
# asia           4.000000              3.0        0.000000          0.750000
# europe         2.307692              3.0        1.384615          0.538462
# northamerica   2.250000              3.0        1.250000          0.750000
# southamerica   1.666667              3.0        2.166667          0.333333
#
#               juegos_perdidos  goles_favor  goles_contra    puntos  \
# continent
# africa               1.800000     3.600000      5.600000  2.400000
# asia                 2.250000     2.250000      6.250000  0.750000
# europe               1.076923     4.769231      4.000000  4.692308
# northamerica         1.000000     3.250000      3.500000  4.500000
# southamerica         0.500000     5.666667      2.833333  6.833333
#
#               clasificado  ha_ganado  ha_perdido
# continent
# ...

# %%
df.groupby(['continent']).mean()['ha_perdido']*100
# Out:
# continent
# africa           0.000000
# asia             0.000000
# europe          30.769231
# northamerica    50.000000
# southamerica    50.000000
# Name: ha_perdido, dtype: float64

# %% [markdown]
# Basado en la tabla anterior, los continentes con mayor probabilidad de tener paises sin juegos perdidos son Southamerica y Northamerica.
