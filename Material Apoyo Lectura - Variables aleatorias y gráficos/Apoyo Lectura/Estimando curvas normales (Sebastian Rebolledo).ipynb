# %% [markdown]
# **Desafio 1**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('subsample_<sebastian_rebolledo>_demo.csv')

# %%
df
# Out:
#     Unnamed: 0  undp_hdi ccodealp      ht_region    gle_cgdpc    imf_pop  \
# 0           76     0.615      IND      SouthAsia   4256.79000        NaN
# 1          150     0.845      SAU    NorthAfrica  20872.71100  30.770000
# 2          177     0.764      TUR    NorthAfrica  16900.71100  77.695999
# 3           54     0.441      ETH    SubSaharian    900.77002  88.347000
# 4          167     0.909      SWE     WesternDem  39000.91000   9.645000
# ..         ...       ...      ...            ...          ...        ...
# 92         178     0.688      TKM     EastEurope  13217.39000        NaN
# 93         171     0.738      THA  SouthEastAsia   9295.57030  68.656998
# 94          17     0.671      BOL          LatAm   4023.87010  10.078000
# 95           0     0.479      AFG      SouthAsia   1282.64000  29.825001
# 96         172     0.484      TGO    SubSaharian   1036.28000   6.929000
#
#     wef_imort  who_alc2000  who_tobt   wdi_exph
# ...

# %% [markdown]
# **Desafio 2**

# %%
import ancilliary_funcs as my_func

# %%
my_func.observaciones_perdidas(df, 'undp_hdi')
# Out:
# La cantidad de datos perdido en la variable 'undp_hdi' es de 3, lo que representa un de 3.1% de datos perdidos.

# %%
my_func.observaciones_perdidas(df, 'gle_cgdpc')
# Out:
# La cantidad de datos perdido en la variable 'gle_cgdpc' es de 1, lo que representa un de 1.0% de datos perdidos.

# %%
my_func.observaciones_perdidas(df, 'imf_pop')
# Out:
# La cantidad de datos perdido en la variable 'imf_pop' es de 26, lo que representa un de 26.8% de datos perdidos.

# %%
my_func.observaciones_perdidas(df, 'wef_imort')
# Out:
# La cantidad de datos perdido en la variable 'wef_imort' es de 20, lo que representa un de 20.599999999999998% de datos perdidos.

# %%
my_func.observaciones_perdidas(df, 'who_alc2000')
# Out:
# La cantidad de datos perdido en la variable 'who_alc2000' es de 5, lo que representa un de 5.2% de datos perdidos.

# %%
my_func.observaciones_perdidas(df, 'who_tobt')
# Out:
# La cantidad de datos perdido en la variable 'who_tobt' es de 36, lo que representa un de 37.1% de datos perdidos.

# %%
my_func.observaciones_perdidas(df, 'wdi_exph')
# Out:
# La cantidad de datos perdido en la variable 'wdi_exph' es de 1, lo que representa un de 1.0% de datos perdidos.

# %% [markdown]
# **Desafio 3**

# %%
mu_wdi_exph = df['wdi_exph'].dropna().mean()
std_wdi_exph = df['wdi_exph'].dropna().std()
mu_wdi_exph
# Out:
# 6.576384648680687

# %%
std_wdi_exph
# Out:
# 2.850159851803415

# %%
df['z_wdi_exph'] = np.where(df['wdi_exph'].notna(), (df['wdi_exph'] - mu_wdi_exph)/std_wdi_exph, np.NaN)

# %%
df
# Out:
#     Unnamed: 0  undp_hdi ccodealp      ht_region    gle_cgdpc    imf_pop  \
# 0           76     0.615      IND      SouthAsia   4256.79000        NaN
# 1          150     0.845      SAU    NorthAfrica  20872.71100  30.770000
# 2          177     0.764      TUR    NorthAfrica  16900.71100  77.695999
# 3           54     0.441      ETH    SubSaharian    900.77002  88.347000
# 4          167     0.909      SWE     WesternDem  39000.91000   9.645000
# ..         ...       ...      ...            ...          ...        ...
# 92         178     0.688      TKM     EastEurope  13217.39000        NaN
# 93         171     0.738      THA  SouthEastAsia   9295.57030  68.656998
# 94          17     0.671      BOL          LatAm   4023.87010  10.078000
# 95           0     0.479      AFG      SouthAsia   1282.64000  29.825001
# 96         172     0.484      TGO    SubSaharian   1036.28000   6.929000
#
#     wef_imort  who_alc2000  who_tobt   wdi_exph  z_wdi_exph
# ...

# %%
df.sort_values(by=['z_wdi_exph'], ascending=False)
# Out:
#     Unnamed: 0  undp_hdi ccodealp      ht_region   gle_cgdpc     imf_pop  \
# 26         186     0.918      USA     WesternDem  47769.6990  318.789001
# 53         129       NaN      MHL        Pacific   2833.9700    0.054000
# 4          167     0.909      SWE     WesternDem  39000.9100    9.645000
# 87         168     0.938      CHE     WesternDem  50454.4100    8.140000
# 66          64     0.924      DEU     WesternDem  39486.6990   80.983002
# ..         ...       ...      ...            ...         ...         ...
# 52          25     0.552      MMR  SouthEastAsia   5733.3701   51.418999
# 92         178     0.688      TKM     EastEurope  13217.3900         NaN
# 30          93     0.582      LAO  SouthEastAsia   2926.7700    6.898000
# 54         140     0.603      TLS  SouthEastAsia   1957.8101    1.146000
# 7          159       NaN      SOM    SubSaharian   1436.7400         NaN
#
#     wef_imort  who_alc2000   who_tobt   wdi_exph  z_wdi_exph
# ...

# %%
subset_df = df.dropna(subset=['z_wdi_exph'])
subset_df = subset_df.sort_values(by=['z_wdi_exph'])
subset_df
# Out:
#     Unnamed: 0  undp_hdi ccodealp      ht_region   gle_cgdpc     imf_pop  \
# 54         140     0.603      TLS  SouthEastAsia   1957.8101    1.146000
# 30          93     0.582      LAO  SouthEastAsia   2926.7700    6.898000
# 92         178     0.688      TKM     EastEurope  13217.3900         NaN
# 52          25     0.552      MMR  SouthEastAsia   5733.3701   51.418999
# 58         131     0.548      PAK      SouthAsia   2855.5500  186.190002
# ..         ...       ...      ...            ...         ...         ...
# 66          64     0.924      DEU     WesternDem  39486.6990   80.983002
# 87         168     0.938      CHE     WesternDem  50454.4100    8.140000
# 4          167     0.909      SWE     WesternDem  39000.9100    9.645000
# 53         129       NaN      MHL        Pacific   2833.9700    0.054000
# 26         186     0.918      USA     WesternDem  47769.6990  318.789001
#
#     wef_imort  who_alc2000   who_tobt   wdi_exph  z_wdi_exph
# ...

# %% [markdown]
# **Seleccionen las primeras y últimas 10 observaciones de la base reordenada. ¿Qué características en común se encuentran?**

# %%
subset_df.head(10)
# Out:
#     Unnamed: 0  undp_hdi ccodealp      ht_region   gle_cgdpc     imf_pop  \
# 54         140     0.603      TLS  SouthEastAsia   1957.8101    1.146000
# 30          93     0.582      LAO  SouthEastAsia   2926.7700    6.898000
# 92         178     0.688      TKM     EastEurope  13217.3900         NaN
# 52          25     0.552      MMR  SouthEastAsia   5733.3701   51.418999
# 58         131     0.548      PAK      SouthAsia   2855.5500  186.190002
# 90          23     0.864      BRN  SouthEastAsia  46103.8400    0.412000
# 25          91     0.799      KWT    NorthAfrica  64342.7110    3.999000
# 45           4     0.531      AGO    SubSaharian   3771.2000   25.789000
# 55         119       NaN      NRU        Pacific   3130.4700    0.012000
# 18         153     0.781      SYC    SubSaharian   9583.3203    0.090000
#
#     wef_imort  who_alc2000   who_tobt  wdi_exph  z_wdi_exph
# 54  47.799999         0.50        NaN  1.475303   -1.789753
# ...

# %%
subset_df.tail(10)
# Out:
#     Unnamed: 0  undp_hdi ccodealp    ht_region    gle_cgdpc     imf_pop  \
# 89          30     0.919      CAN   WesternDem  36577.07800   35.495998
# 14         121     0.923      NLD   WesternDem  42258.35200   16.865000
# 21          44     0.773      CUB        LatAm   5899.93990         NaN
# 48         154     0.431      SLE  SubSaharian    979.95001    6.232000
# 22           9     0.892      AUT   WesternDem  38868.03900    8.544000
# 66          64     0.924      DEU   WesternDem  39486.69900   80.983002
# 87         168     0.938      CHE   WesternDem  50454.41000    8.140000
# 4          167     0.909      SWE   WesternDem  39000.91000    9.645000
# 53         129       NaN      MHL      Pacific   2833.97000    0.054000
# 26         186     0.918      USA   WesternDem  47769.69900  318.789001
#
#      wef_imort  who_alc2000   who_tobt   wdi_exph  z_wdi_exph
# 89    4.700000         8.10  16.200001  10.449582    1.358940
# ...

# %% [markdown]
# La caracteristicas comunes son que sus valores absolutos son similares y que ambos estan alejados una distancia similar de la media, la cual tiene un valor de 0.

# %% [markdown]
# **Desafio 4**

# %%
z_mean_region = subset_df.groupby('ht_region').mean()['z_wdi_exph']
z_mean_region
# Out:
# ht_region
# Caribbean       -0.248007
# EastAsia        -0.242966
# EastEurope      -0.015340
# LatAm            0.524952
# NorthAfrica     -0.364767
# Pacific         -0.078684
# SouthAsia       -0.642149
# SouthEastAsia   -1.193068
# SubSaharian     -0.219256
# WesternDem       1.355330
# Name: z_wdi_exph, dtype: float64

# %%
plt.title('Media de la variable estandarizada por Region')
plt.plot(z_mean_region.values, z_mean_region.index, 'o', color = 'grey')
plt.axvline(subset_df['z_wdi_exph'].mean(), color = 'tomato', linestyle = '--')

# %% [markdown]
# **Desafio 5**

# %%
from scipy.stats import norm

# %%
def densidad_probabilidad(df, variable):
    puntaje_z = []
    mean_variable = df[variable].dropna().mean()
    std_variable = df[variable].dropna().std()
    for valor in df[variable].dropna():
        new_valor = (valor-mean_variable)/std_variable
        puntaje_z.append(new_valor)
    
    puntaje_z.sort()
    plt.plot(puntaje_z, norm.pdf(puntaje_z, 0,1))
    return

# %%
densidad_probabilidad(df, 'imf_pop')

# %%
densidad_probabilidad(df, 'gle_cgdpc')

# %%
densidad_probabilidad(df, 'wdi_exph')
